# %%
import glob
import multiprocessing
import time
import csv
import pickle
import os
import pandas as pd
import shutil
import numpy as np
import warnings
import tqdm
import logging
import mxnet as mx
from bs4 import BeautifulSoup
from urllib.request import urlopen
from os.path import basename
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer, sent_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


# %pylab inline
warnings.filterwarnings("ignore")
# Out:
# /home/dc/anaconda3/envs/mxnet/lib/python3.6/site-packages/scipy/sparse/sparsetools.py:20: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# Populating the interactive namespace from numpy and matplotlib

# %%
# 2d to 4d conversion
def to4d(img):
    return img.reshape(img.shape[0], 1, 32, 32).astype(np.float32)

# %%
p_file = 'RCT_Vectors'
with open(p_file, 'rb') as fin:
    vectors = pickle.load(fin)

# %%
p_file = 'RCT_labels'
with open(p_file, 'rb') as fin:
    data_Y = pickle.load(fin)

# %%
d2v_X_train, d2v_X_test, d2v_Y_train, d2v_Y_test = train_test_split(vectors, data_Y, test_size=0.25)

# %%
X_train_array = np.array(d2v_X_train)
Y_train_array = np.array(d2v_Y_train)
X_test_array = np.array(d2v_X_test)
Y_test_array = np.array(d2v_Y_test)

# %%
# creating 2d and 4d training/testing dataset
batch_size = 64
train_iter = mx.io.NDArrayIter(X_train_array, Y_train_array, batch_size=batch_size, label_name='svm_label')
test_iter = mx.io.NDArrayIter(X_test_array, Y_test_array, batch_size=batch_size, label_name='svm_label')

train_iters = mx.io.NDArrayIter(to4d(X_train_array), Y_train_array, batch_size, shuffle=True,label_name='svm_label')
val_iters = mx.io.NDArrayIter(to4d(X_test_array), Y_test_array, batch_size,label_name='svm_label')

# %%
# Single SVM
data = mx.symbol.Variable('data')
svm  = mx.symbol.FullyConnected(data = data, name='fc', num_hidden=2)


# Here we add the ultimate layer based on L2-SVM objective
ssvm = mx.symbol.SVMOutput(data=svm, name='svm')

# %%
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

mod = mx.model.FeedForward(
    ctx = mx.gpu(0),     # use GPU 0 for training, others are same as before
    symbol = ssvm,       # network structure
    num_epoch = 100,     # number of data passes for training 
    learning_rate = 0.01 # learning rate of SGD 
)
mod.fit(
    X=train_iters,       # training data
    eval_data=val_iters, # validation data
    batch_end_callback = mx.callback.Speedometer(batch_size, 64) # output progress for each 200 data batches
)
# Out:
# INFO:root:Start training with [gpu(0)]
# INFO:root:Epoch[0] Batch [64]	Speed: 132987.59 samples/sec	accuracy=0.840088
# INFO:root:Epoch[0] Resetting Data Iterator
# INFO:root:Epoch[0] Time cost=0.066
# INFO:root:Epoch[0] Validation-accuracy=0.833594
# INFO:root:Epoch[1] Batch [64]	Speed: 118498.20 samples/sec	accuracy=0.848633
# INFO:root:Epoch[1] Resetting Data Iterator
# INFO:root:Epoch[1] Time cost=0.069
# INFO:root:Epoch[1] Validation-accuracy=0.830469
# INFO:root:Epoch[2] Batch [64]	Speed: 114123.14 samples/sec	accuracy=0.849365
# INFO:root:Epoch[2] Resetting Data Iterator
# INFO:root:Epoch[2] Time cost=0.068
# INFO:root:Epoch[2] Validation-accuracy=0.825000
# INFO:root:Epoch[3] Batch [64]	Speed: 103186.74 samples/sec	accuracy=0.850342
# INFO:root:Epoch[3] Resetting Data Iterator
# INFO:root:Epoch[3] Time cost=0.072
# INFO:root:Epoch[3] Validation-accuracy=0.819531
# INFO:root:Epoch[4] Batch [64]	Speed: 109783.94 samples/sec	accuracy=0.850830
# INFO:root:Epoch[4] Resetting Data Iterator
# INFO:root:Epoch[4] Time cost=0.067
# INFO:root:Epoch[4] Validation-accuracy=0.812500
# INFO:root:Epoch[5] Batch [64]	Speed: 125051.82 samples/sec	accuracy=0.851074
# INFO:root:Epoch[5] Resetting Data Iterator
# INFO:root:Epoch[5] Time cost=0.064
# INFO:root:Epoch[5] Validation-accuracy=0.809375
# INFO:root:Epoch[6] Batch [64]	Speed: 123918.01 samples/sec	accuracy=0.850098
# INFO:root:Epoch[6] Resetting Data Iterator
# INFO:root:Epoch[6] Time cost=0.063
# INFO:root:Epoch[6] Validation-accuracy=0.808203
# INFO:root:Epoch[7] Batch [64]	Speed: 119190.42 samples/sec	accuracy=0.850342
# INFO:root:Epoch[7] Resetting Data Iterator
# INFO:root:Epoch[7] Time cost=0.072
# INFO:root:Epoch[7] Validation-accuracy=0.806641
# INFO:root:Epoch[8] Batch [64]	Speed: 108839.43 samples/sec	accuracy=0.849854
# INFO:root:Epoch[8] Resetting Data Iterator
# INFO:root:Epoch[8] Time cost=0.070
# INFO:root:Epoch[8] Validation-accuracy=0.803906
# INFO:root:Epoch[9] Batch [64]	Speed: 114841.77 samples/sec	accuracy=0.849854
# INFO:root:Epoch[9] Resetting Data Iterator
# INFO:root:Epoch[9] Time cost=0.073
# INFO:root:Epoch[9] Validation-accuracy=0.804297
# INFO:root:Epoch[10] Batch [64]	Speed: 115348.36 samples/sec	accuracy=0.849609
# INFO:root:Epoch[10] Resetting Data Iterator
# INFO:root:Epoch[10] Time cost=0.067
# INFO:root:Epoch[10] Validation-accuracy=0.804297
# INFO:root:Epoch[11] Batch [64]	Speed: 115229.21 samples/sec	accuracy=0.850098
# INFO:root:Epoch[11] Resetting Data Iterator
# INFO:root:Epoch[11] Time cost=0.066
# INFO:root:Epoch[11] Validation-accuracy=0.803125
# INFO:root:Epoch[12] Batch [64]	Speed: 121247.98 samples/sec	accuracy=0.849854
# INFO:root:Epoch[12] Resetting Data Iterator
# INFO:root:Epoch[12] Time cost=0.065
# INFO:root:Epoch[12] Validation-accuracy=0.802734
# INFO:root:Epoch[13] Batch [64]	Speed: 114505.74 samples/sec	accuracy=0.849854
# INFO:root:Epoch[13] Resetting Data Iterator
# INFO:root:Epoch[13] Time cost=0.070
# INFO:root:Epoch[13] Validation-accuracy=0.801953
# INFO:root:Epoch[14] Batch [64]	Speed: 115346.04 samples/sec	accuracy=0.849609
# INFO:root:Epoch[14] Resetting Data Iterator
# INFO:root:Epoch[14] Time cost=0.064
# INFO:root:Epoch[14] Validation-accuracy=0.801953
# INFO:root:Epoch[15] Batch [64]	Speed: 118456.53 samples/sec	accuracy=0.849609
# INFO:root:Epoch[15] Resetting Data Iterator
# INFO:root:Epoch[15] Time cost=0.068
# INFO:root:Epoch[15] Validation-accuracy=0.801562
# INFO:root:Epoch[16] Batch [64]	Speed: 118111.23 samples/sec	accuracy=0.849854
# INFO:root:Epoch[16] Resetting Data Iterator
# INFO:root:Epoch[16] Time cost=0.065
# INFO:root:Epoch[16] Validation-accuracy=0.800781
# INFO:root:Epoch[17] Batch [64]	Speed: 100812.55 samples/sec	accuracy=0.849854
# INFO:root:Epoch[17] Resetting Data Iterator
# INFO:root:Epoch[17] Time cost=0.067
# INFO:root:Epoch[17] Validation-accuracy=0.800781
# INFO:root:Epoch[18] Batch [64]	Speed: 105388.92 samples/sec	accuracy=0.850098
# INFO:root:Epoch[18] Resetting Data Iterator
# INFO:root:Epoch[18] Time cost=0.067
# INFO:root:Epoch[18] Validation-accuracy=0.800391
# INFO:root:Epoch[19] Batch [64]	Speed: 122841.46 samples/sec	accuracy=0.850098
# INFO:root:Epoch[19] Resetting Data Iterator
# INFO:root:Epoch[19] Time cost=0.064
# INFO:root:Epoch[19] Validation-accuracy=0.800391
# INFO:root:Epoch[20] Batch [64]	Speed: 121723.05 samples/sec	accuracy=0.850342
# INFO:root:Epoch[20] Resetting Data Iterator
# INFO:root:Epoch[20] Time cost=0.063
# INFO:root:Epoch[20] Validation-accuracy=0.801172
# INFO:root:Epoch[21] Batch [64]	Speed: 122075.07 samples/sec	accuracy=0.850342
# INFO:root:Epoch[21] Resetting Data Iterator
# INFO:root:Epoch[21] Time cost=0.062
# INFO:root:Epoch[21] Validation-accuracy=0.800781
# INFO:root:Epoch[22] Batch [64]	Speed: 118979.11 samples/sec	accuracy=0.850342
# INFO:root:Epoch[22] Resetting Data Iterator
# INFO:root:Epoch[22] Time cost=0.069
# INFO:root:Epoch[22] Validation-accuracy=0.800781
# INFO:root:Epoch[23] Batch [64]	Speed: 129370.38 samples/sec	accuracy=0.850342
# INFO:root:Epoch[23] Resetting Data Iterator
# INFO:root:Epoch[23] Time cost=0.069
# INFO:root:Epoch[23] Validation-accuracy=0.800781
# INFO:root:Epoch[24] Batch [64]	Speed: 123768.92 samples/sec	accuracy=0.849854
# INFO:root:Epoch[24] Resetting Data Iterator
# INFO:root:Epoch[24] Time cost=0.065
# INFO:root:Epoch[24] Validation-accuracy=0.800391
# INFO:root:Epoch[25] Batch [64]	Speed: 108199.88 samples/sec	accuracy=0.849854
# INFO:root:Epoch[25] Resetting Data Iterator
# INFO:root:Epoch[25] Time cost=0.065
# INFO:root:Epoch[25] Validation-accuracy=0.800391
# INFO:root:Epoch[26] Batch [64]	Speed: 129064.23 samples/sec	accuracy=0.849854
# INFO:root:Epoch[26] Resetting Data Iterator
# INFO:root:Epoch[26] Time cost=0.064
# INFO:root:Epoch[26] Validation-accuracy=0.800391
# INFO:root:Epoch[27] Batch [64]	Speed: 136320.04 samples/sec	accuracy=0.849854
# INFO:root:Epoch[27] Resetting Data Iterator
# INFO:root:Epoch[27] Time cost=0.059
# INFO:root:Epoch[27] Validation-accuracy=0.800391
# INFO:root:Epoch[28] Batch [64]	Speed: 166408.71 samples/sec	accuracy=0.849854
# INFO:root:Epoch[28] Resetting Data Iterator
# INFO:root:Epoch[28] Time cost=0.049
# INFO:root:Epoch[28] Validation-accuracy=0.800391
# INFO:root:Epoch[29] Batch [64]	Speed: 152065.19 samples/sec	accuracy=0.849854
# INFO:root:Epoch[29] Resetting Data Iterator
# INFO:root:Epoch[29] Time cost=0.052
# INFO:root:Epoch[29] Validation-accuracy=0.800391
# INFO:root:Epoch[30] Batch [64]	Speed: 152960.12 samples/sec	accuracy=0.849854
# INFO:root:Epoch[30] Resetting Data Iterator
# INFO:root:Epoch[30] Time cost=0.052
# INFO:root:Epoch[30] Validation-accuracy=0.800391
# INFO:root:Epoch[31] Batch [64]	Speed: 175870.08 samples/sec	accuracy=0.849854
# INFO:root:Epoch[31] Resetting Data Iterator
# INFO:root:Epoch[31] Time cost=0.050
# INFO:root:Epoch[31] Validation-accuracy=0.800391
# INFO:root:Epoch[32] Batch [64]	Speed: 177606.42 samples/sec	accuracy=0.849854
# INFO:root:Epoch[32] Resetting Data Iterator
# INFO:root:Epoch[32] Time cost=0.050
# INFO:root:Epoch[32] Validation-accuracy=0.800391
# INFO:root:Epoch[33] Batch [64]	Speed: 165990.68 samples/sec	accuracy=0.849854
# INFO:root:Epoch[33] Resetting Data Iterator
# INFO:root:Epoch[33] Time cost=0.049
# INFO:root:Epoch[33] Validation-accuracy=0.800391
# INFO:root:Epoch[34] Batch [64]	Speed: 174377.74 samples/sec	accuracy=0.849854
# INFO:root:Epoch[34] Resetting Data Iterator
# INFO:root:Epoch[34] Time cost=0.049
# INFO:root:Epoch[34] Validation-accuracy=0.800391
# INFO:root:Epoch[35] Batch [64]	Speed: 171146.62 samples/sec	accuracy=0.849854
# INFO:root:Epoch[35] Resetting Data Iterator
# INFO:root:Epoch[35] Time cost=0.049
# INFO:root:Epoch[35] Validation-accuracy=0.800391
# INFO:root:Epoch[36] Batch [64]	Speed: 162052.83 samples/sec	accuracy=0.849854
# INFO:root:Epoch[36] Resetting Data Iterator
# INFO:root:Epoch[36] Time cost=0.051
# INFO:root:Epoch[36] Validation-accuracy=0.800000
# INFO:root:Epoch[37] Batch [64]	Speed: 147381.93 samples/sec	accuracy=0.849854
# INFO:root:Epoch[37] Resetting Data Iterator
# INFO:root:Epoch[37] Time cost=0.064
# INFO:root:Epoch[37] Validation-accuracy=0.800000
# INFO:root:Epoch[38] Batch [64]	Speed: 162635.79 samples/sec	accuracy=0.849854
# INFO:root:Epoch[38] Resetting Data Iterator
# INFO:root:Epoch[38] Time cost=0.051
# INFO:root:Epoch[38] Validation-accuracy=0.800391
# INFO:root:Epoch[39] Batch [64]	Speed: 165216.47 samples/sec	accuracy=0.849854
# INFO:root:Epoch[39] Resetting Data Iterator
# INFO:root:Epoch[39] Time cost=0.049
# INFO:root:Epoch[39] Validation-accuracy=0.800391
# INFO:root:Epoch[40] Batch [64]	Speed: 159378.34 samples/sec	accuracy=0.849854
# INFO:root:Epoch[40] Resetting Data Iterator
# INFO:root:Epoch[40] Time cost=0.056
# INFO:root:Epoch[40] Validation-accuracy=0.800391
# INFO:root:Epoch[41] Batch [64]	Speed: 168847.24 samples/sec	accuracy=0.849854
# INFO:root:Epoch[41] Resetting Data Iterator
# INFO:root:Epoch[41] Time cost=0.051
# INFO:root:Epoch[41] Validation-accuracy=0.800391
# INFO:root:Epoch[42] Batch [64]	Speed: 157453.14 samples/sec	accuracy=0.849854
# INFO:root:Epoch[42] Resetting Data Iterator
# INFO:root:Epoch[42] Time cost=0.051
# INFO:root:Epoch[42] Validation-accuracy=0.800391
# INFO:root:Epoch[43] Batch [64]	Speed: 176406.43 samples/sec	accuracy=0.849854
# INFO:root:Epoch[43] Resetting Data Iterator
# INFO:root:Epoch[43] Time cost=0.046
# INFO:root:Epoch[43] Validation-accuracy=0.800391
# INFO:root:Epoch[44] Batch [64]	Speed: 164230.93 samples/sec	accuracy=0.849854
# INFO:root:Epoch[44] Resetting Data Iterator
# INFO:root:Epoch[44] Time cost=0.052
# INFO:root:Epoch[44] Validation-accuracy=0.800391
# INFO:root:Epoch[45] Batch [64]	Speed: 136176.33 samples/sec	accuracy=0.849854
# INFO:root:Epoch[45] Resetting Data Iterator
# INFO:root:Epoch[45] Time cost=0.059
# INFO:root:Epoch[45] Validation-accuracy=0.800391
# INFO:root:Epoch[46] Batch [64]	Speed: 163502.57 samples/sec	accuracy=0.849854
# INFO:root:Epoch[46] Resetting Data Iterator
# INFO:root:Epoch[46] Time cost=0.050
# INFO:root:Epoch[46] Validation-accuracy=0.800391
# INFO:root:Epoch[47] Batch [64]	Speed: 135124.54 samples/sec	accuracy=0.849854
# INFO:root:Epoch[47] Resetting Data Iterator
# INFO:root:Epoch[47] Time cost=0.055
# INFO:root:Epoch[47] Validation-accuracy=0.800391
# INFO:root:Epoch[48] Batch [64]	Speed: 154936.91 samples/sec	accuracy=0.849854
# INFO:root:Epoch[48] Resetting Data Iterator
# INFO:root:Epoch[48] Time cost=0.052
# INFO:root:Epoch[48] Validation-accuracy=0.800391
# INFO:root:Epoch[49] Batch [64]	Speed: 162323.85 samples/sec	accuracy=0.849854
# INFO:root:Epoch[49] Resetting Data Iterator
# INFO:root:Epoch[49] Time cost=0.057
# INFO:root:Epoch[49] Validation-accuracy=0.800391
# INFO:root:Epoch[50] Batch [64]	Speed: 173871.24 samples/sec	accuracy=0.849854
# INFO:root:Epoch[50] Resetting Data Iterator
# INFO:root:Epoch[50] Time cost=0.048
# INFO:root:Epoch[50] Validation-accuracy=0.800391
# INFO:root:Epoch[51] Batch [64]	Speed: 162014.63 samples/sec	accuracy=0.849854
# INFO:root:Epoch[51] Resetting Data Iterator
# INFO:root:Epoch[51] Time cost=0.051
# INFO:root:Epoch[51] Validation-accuracy=0.800391
# INFO:root:Epoch[52] Batch [64]	Speed: 161269.41 samples/sec	accuracy=0.849854
# INFO:root:Epoch[52] Resetting Data Iterator
# INFO:root:Epoch[52] Time cost=0.054
# INFO:root:Epoch[52] Validation-accuracy=0.800391
# INFO:root:Epoch[53] Batch [64]	Speed: 170806.31 samples/sec	accuracy=0.849854
# INFO:root:Epoch[53] Resetting Data Iterator
# INFO:root:Epoch[53] Time cost=0.049
# INFO:root:Epoch[53] Validation-accuracy=0.800391
# INFO:root:Epoch[54] Batch [64]	Speed: 162178.28 samples/sec	accuracy=0.849854
# INFO:root:Epoch[54] Resetting Data Iterator
# INFO:root:Epoch[54] Time cost=0.054
# INFO:root:Epoch[54] Validation-accuracy=0.800000
# INFO:root:Epoch[55] Batch [64]	Speed: 164534.49 samples/sec	accuracy=0.849854
# INFO:root:Epoch[55] Resetting Data Iterator
# INFO:root:Epoch[55] Time cost=0.051
# INFO:root:Epoch[55] Validation-accuracy=0.800000
# INFO:root:Epoch[56] Batch [64]	Speed: 166107.84 samples/sec	accuracy=0.849854
# INFO:root:Epoch[56] Resetting Data Iterator
# INFO:root:Epoch[56] Time cost=0.049
# INFO:root:Epoch[56] Validation-accuracy=0.800000
# INFO:root:Epoch[57] Batch [64]	Speed: 146782.54 samples/sec	accuracy=0.849854
# INFO:root:Epoch[57] Resetting Data Iterator
# INFO:root:Epoch[57] Time cost=0.056
# INFO:root:Epoch[57] Validation-accuracy=0.800000
# INFO:root:Epoch[58] Batch [64]	Speed: 111693.95 samples/sec	accuracy=0.849854
# INFO:root:Epoch[58] Resetting Data Iterator
# INFO:root:Epoch[58] Time cost=0.062
# INFO:root:Epoch[58] Validation-accuracy=0.800000
# INFO:root:Epoch[59] Batch [64]	Speed: 169617.41 samples/sec	accuracy=0.849854
# INFO:root:Epoch[59] Resetting Data Iterator
# INFO:root:Epoch[59] Time cost=0.051
# INFO:root:Epoch[59] Validation-accuracy=0.800000
# INFO:root:Epoch[60] Batch [64]	Speed: 161833.01 samples/sec	accuracy=0.849854
# INFO:root:Epoch[60] Resetting Data Iterator
# INFO:root:Epoch[60] Time cost=0.052
# INFO:root:Epoch[60] Validation-accuracy=0.800000
# INFO:root:Epoch[61] Batch [64]	Speed: 164959.47 samples/sec	accuracy=0.849854
# INFO:root:Epoch[61] Resetting Data Iterator
# INFO:root:Epoch[61] Time cost=0.050
# INFO:root:Epoch[61] Validation-accuracy=0.799609
# INFO:root:Epoch[62] Batch [64]	Speed: 156677.72 samples/sec	accuracy=0.849854
# INFO:root:Epoch[62] Resetting Data Iterator
# INFO:root:Epoch[62] Time cost=0.051
# INFO:root:Epoch[62] Validation-accuracy=0.799609
# INFO:root:Epoch[63] Batch [64]	Speed: 174620.56 samples/sec	accuracy=0.849854
# INFO:root:Epoch[63] Resetting Data Iterator
# INFO:root:Epoch[63] Time cost=0.049
# INFO:root:Epoch[63] Validation-accuracy=0.799609
# INFO:root:Epoch[64] Batch [64]	Speed: 170289.92 samples/sec	accuracy=0.849854
# INFO:root:Epoch[64] Resetting Data Iterator
# INFO:root:Epoch[64] Time cost=0.047
# INFO:root:Epoch[64] Validation-accuracy=0.799609
# INFO:root:Epoch[65] Batch [64]	Speed: 163663.00 samples/sec	accuracy=0.849854
# INFO:root:Epoch[65] Resetting Data Iterator
# INFO:root:Epoch[65] Time cost=0.057
# INFO:root:Epoch[65] Validation-accuracy=0.799609
# INFO:root:Epoch[66] Batch [64]	Speed: 163027.80 samples/sec	accuracy=0.849854
# INFO:root:Epoch[66] Resetting Data Iterator
# INFO:root:Epoch[66] Time cost=0.050
# INFO:root:Epoch[66] Validation-accuracy=0.799609
# INFO:root:Epoch[67] Batch [64]	Speed: 166229.99 samples/sec	accuracy=0.849854
# INFO:root:Epoch[67] Resetting Data Iterator
# INFO:root:Epoch[67] Time cost=0.050
# INFO:root:Epoch[67] Validation-accuracy=0.799609
# INFO:root:Epoch[68] Batch [64]	Speed: 156466.54 samples/sec	accuracy=0.849854
# INFO:root:Epoch[68] Resetting Data Iterator
# INFO:root:Epoch[68] Time cost=0.059
# INFO:root:Epoch[68] Validation-accuracy=0.799609
# INFO:root:Epoch[69] Batch [64]	Speed: 157054.42 samples/sec	accuracy=0.849854
# INFO:root:Epoch[69] Resetting Data Iterator
# INFO:root:Epoch[69] Time cost=0.050
# INFO:root:Epoch[69] Validation-accuracy=0.799609
# INFO:root:Epoch[70] Batch [64]	Speed: 154762.44 samples/sec	accuracy=0.850098
# INFO:root:Epoch[70] Resetting Data Iterator
# INFO:root:Epoch[70] Time cost=0.052
# INFO:root:Epoch[70] Validation-accuracy=0.799219
# INFO:root:Epoch[71] Batch [64]	Speed: 149164.47 samples/sec	accuracy=0.850098
# INFO:root:Epoch[71] Resetting Data Iterator
# INFO:root:Epoch[71] Time cost=0.057
# INFO:root:Epoch[71] Validation-accuracy=0.799219
# INFO:root:Epoch[72] Batch [64]	Speed: 150068.74 samples/sec	accuracy=0.850098
# INFO:root:Epoch[72] Resetting Data Iterator
# INFO:root:Epoch[72] Time cost=0.052
# INFO:root:Epoch[72] Validation-accuracy=0.799219
# INFO:root:Epoch[73] Batch [64]	Speed: 106555.70 samples/sec	accuracy=0.850098
# INFO:root:Epoch[73] Resetting Data Iterator
# INFO:root:Epoch[73] Time cost=0.072
# INFO:root:Epoch[73] Validation-accuracy=0.799219
# INFO:root:Epoch[74] Batch [64]	Speed: 164608.59 samples/sec	accuracy=0.850098
# INFO:root:Epoch[74] Resetting Data Iterator
# INFO:root:Epoch[74] Time cost=0.048
# INFO:root:Epoch[74] Validation-accuracy=0.799219
# INFO:root:Epoch[75] Batch [64]	Speed: 151610.27 samples/sec	accuracy=0.850098
# INFO:root:Epoch[75] Resetting Data Iterator
# INFO:root:Epoch[75] Time cost=0.051
# INFO:root:Epoch[75] Validation-accuracy=0.799219
# INFO:root:Epoch[76] Batch [64]	Speed: 152154.08 samples/sec	accuracy=0.849854
# INFO:root:Epoch[76] Resetting Data Iterator
# INFO:root:Epoch[76] Time cost=0.054
# INFO:root:Epoch[76] Validation-accuracy=0.799219
# INFO:root:Epoch[77] Batch [64]	Speed: 163091.25 samples/sec	accuracy=0.849854
# INFO:root:Epoch[77] Resetting Data Iterator
# INFO:root:Epoch[77] Time cost=0.050
# INFO:root:Epoch[77] Validation-accuracy=0.799219
# INFO:root:Epoch[78] Batch [64]	Speed: 161889.44 samples/sec	accuracy=0.849854
# INFO:root:Epoch[78] Resetting Data Iterator
# INFO:root:Epoch[78] Time cost=0.061
# INFO:root:Epoch[78] Validation-accuracy=0.799219
# INFO:root:Epoch[79] Batch [64]	Speed: 147328.84 samples/sec	accuracy=0.849854
# INFO:root:Epoch[79] Resetting Data Iterator
# INFO:root:Epoch[79] Time cost=0.053
# INFO:root:Epoch[79] Validation-accuracy=0.799219
# INFO:root:Epoch[80] Batch [64]	Speed: 156584.90 samples/sec	accuracy=0.849854
# INFO:root:Epoch[80] Resetting Data Iterator
# INFO:root:Epoch[80] Time cost=0.057
# INFO:root:Epoch[80] Validation-accuracy=0.799219
# INFO:root:Epoch[81] Batch [64]	Speed: 136927.39 samples/sec	accuracy=0.849854
# INFO:root:Epoch[81] Resetting Data Iterator
# INFO:root:Epoch[81] Time cost=0.058
# INFO:root:Epoch[81] Validation-accuracy=0.799219
# INFO:root:Epoch[82] Batch [64]	Speed: 143602.37 samples/sec	accuracy=0.849854
# INFO:root:Epoch[82] Resetting Data Iterator
# INFO:root:Epoch[82] Time cost=0.052
# INFO:root:Epoch[82] Validation-accuracy=0.799219
# INFO:root:Epoch[83] Batch [64]	Speed: 154548.04 samples/sec	accuracy=0.849854
# INFO:root:Epoch[83] Resetting Data Iterator
# INFO:root:Epoch[83] Time cost=0.051
# INFO:root:Epoch[83] Validation-accuracy=0.799219
# INFO:root:Epoch[84] Batch [64]	Speed: 167047.85 samples/sec	accuracy=0.849854
# INFO:root:Epoch[84] Resetting Data Iterator
# INFO:root:Epoch[84] Time cost=0.048
# INFO:root:Epoch[84] Validation-accuracy=0.799219
# INFO:root:Epoch[85] Batch [64]	Speed: 162118.59 samples/sec	accuracy=0.849854
# INFO:root:Epoch[85] Resetting Data Iterator
# INFO:root:Epoch[85] Time cost=0.050
# INFO:root:Epoch[85] Validation-accuracy=0.799219
# INFO:root:Epoch[86] Batch [64]	Speed: 158437.65 samples/sec	accuracy=0.849854
# INFO:root:Epoch[86] Resetting Data Iterator
# INFO:root:Epoch[86] Time cost=0.052
# INFO:root:Epoch[86] Validation-accuracy=0.799219
# INFO:root:Epoch[87] Batch [64]	Speed: 163648.97 samples/sec	accuracy=0.849854
# INFO:root:Epoch[87] Resetting Data Iterator
# INFO:root:Epoch[87] Time cost=0.053
# INFO:root:Epoch[87] Validation-accuracy=0.799219
# INFO:root:Epoch[88] Batch [64]	Speed: 124697.83 samples/sec	accuracy=0.849854
# INFO:root:Epoch[88] Resetting Data Iterator
# INFO:root:Epoch[88] Time cost=0.061
# INFO:root:Epoch[88] Validation-accuracy=0.799219
# INFO:root:Epoch[89] Batch [64]	Speed: 166764.08 samples/sec	accuracy=0.849854
# INFO:root:Epoch[89] Resetting Data Iterator
# INFO:root:Epoch[89] Time cost=0.050
# INFO:root:Epoch[89] Validation-accuracy=0.799219
# INFO:root:Epoch[90] Batch [64]	Speed: 146689.80 samples/sec	accuracy=0.849854
# INFO:root:Epoch[90] Resetting Data Iterator
# INFO:root:Epoch[90] Time cost=0.054
# INFO:root:Epoch[90] Validation-accuracy=0.799219
# INFO:root:Epoch[91] Batch [64]	Speed: 168471.38 samples/sec	accuracy=0.849854
# INFO:root:Epoch[91] Resetting Data Iterator
# INFO:root:Epoch[91] Time cost=0.052
# INFO:root:Epoch[91] Validation-accuracy=0.799219
# INFO:root:Epoch[92] Batch [64]	Speed: 161461.90 samples/sec	accuracy=0.849854
# INFO:root:Epoch[92] Resetting Data Iterator
# INFO:root:Epoch[92] Time cost=0.049
# INFO:root:Epoch[92] Validation-accuracy=0.799219
# INFO:root:Epoch[93] Batch [64]	Speed: 156554.94 samples/sec	accuracy=0.849854
# INFO:root:Epoch[93] Resetting Data Iterator
# INFO:root:Epoch[93] Time cost=0.053
# INFO:root:Epoch[93] Validation-accuracy=0.799219
# INFO:root:Epoch[94] Batch [64]	Speed: 172686.30 samples/sec	accuracy=0.849854
# INFO:root:Epoch[94] Resetting Data Iterator
# INFO:root:Epoch[94] Time cost=0.048
# INFO:root:Epoch[94] Validation-accuracy=0.799219
# INFO:root:Epoch[95] Batch [64]	Speed: 163806.57 samples/sec	accuracy=0.849854
# INFO:root:Epoch[95] Resetting Data Iterator
# INFO:root:Epoch[95] Time cost=0.050
# INFO:root:Epoch[95] Validation-accuracy=0.799219
# INFO:root:Epoch[96] Batch [64]	Speed: 174994.08 samples/sec	accuracy=0.849854
# INFO:root:Epoch[96] Resetting Data Iterator
# INFO:root:Epoch[96] Time cost=0.047
# INFO:root:Epoch[96] Validation-accuracy=0.799219
# INFO:root:Epoch[97] Batch [64]	Speed: 161875.71 samples/sec	accuracy=0.849854
# INFO:root:Epoch[97] Resetting Data Iterator
# INFO:root:Epoch[97] Time cost=0.051
# INFO:root:Epoch[97] Validation-accuracy=0.798828
# INFO:root:Epoch[98] Batch [64]	Speed: 161184.68 samples/sec	accuracy=0.849854
# INFO:root:Epoch[98] Resetting Data Iterator
# INFO:root:Epoch[98] Time cost=0.050
# INFO:root:Epoch[98] Validation-accuracy=0.798828
# INFO:root:Epoch[99] Batch [64]	Speed: 157807.48 samples/sec	accuracy=0.849854
# INFO:root:Epoch[99] Resetting Data Iterator
# INFO:root:Epoch[99] Time cost=0.051
# INFO:root:Epoch[99] Validation-accuracy=0.798828

# %%
# save a model to mymodel-symbol.json and mymodel-0100.params
prefix = 'SVM'
epoch = 100
mod.save(prefix, epoch)

# load model back
model_loaded = mx.model.FeedForward.load(prefix, epoch)
# Out:
# INFO:root:Saved checkpoint to "SVM-0100.params"

# %%
prob = model_loaded.predict(val_iters)
logging.info('Finish predict of one Layer SVM Network...')
# Check the accuracy from prediction
val_iters.reset()

y_batch = []
for dbatch in val_iters:
    label = dbatch.label[0].asnumpy()
    pad = val_iters.getpad()
    real_size = label.shape[0] - pad
    y_batch.append(label[0:real_size])
y = np.concatenate(y_batch)

# Confusion Matrix and report 
py = np.argmax(prob, axis=1)
acc1 = float(np.sum(py == y)) / len(y)
logging.info('Test accuracy = %f', acc1)
cfn_matrix=confusion_matrix(y,py)
print(classification_report (y,py))
print(cfn_matrix)
# Out:
# INFO:root:Finish predict of one Layer SVM Network...
# INFO:root:Test accuracy = 0.798747
#              precision    recall  f1-score   support
#
#         0.0       0.27      0.17      0.21       404
#         1.0       0.85      0.92      0.88      2150
#
# avg / total       0.76      0.80      0.78      2554
#
# [[  67  337]
#  [ 177 1973]]

# %%
# DNN + SVM 
data = mx.symbol.Variable('data')
data = mx.sym.Flatten(data=data)

fc1  = mx.symbol.FullyConnected(data = data, name='fc1', num_hidden=512)
act1 = mx.symbol.Activation(data = fc1, name='relu1', act_type="relu")
fc2  = mx.symbol.FullyConnected(data = act1, name = 'fc2', num_hidden = 512)
act2 = mx.symbol.Activation(data = fc2, name='relu2', act_type="relu")

fc3  = mx.symbol.FullyConnected(data = act2, name='fc3', num_hidden=4)

dnnsvm = mx.symbol.SVMOutput(data=fc3, name='svm')

# draw network chart
shape = {"data" : (batch_size, 1, 32, 32)}
mx.viz.plot_network(symbol=dnnsvm, shape=shape)
network_chart=mx.viz.plot_network(symbol=dnnsvm, shape=shape)
network_chart.render('DNN + SVM')
# Out:
# 'DNN + SVM.pdf'

# %%
mod = mx.mod.Module(
    context = mx.gpu(0),  # Run on GPU 0
    symbol = dnnsvm,        
    label_names = ['svm_label'],
)
mod.fit(
    train_data=train_iters,
    eval_data=val_iters,  
    batch_end_callback = mx.callback.Speedometer(batch_size, batch_size), 
    num_epoch = 100,       # Train for 100 epochs
    optimizer_params = {
        'learning_rate': 0.001,  # Learning rate
        'momentum': 0.9,       # Momentum for SGD with momentum
        'wd': 0.001,         # Weight decay for regularization
    },
)
print('Accuracy:', mod.score(val_iters, mx.metric.Accuracy())[0][1]*100, '%')
# Out:
# INFO:root:Epoch[0] Batch [64]	Speed: 78033.21 samples/sec	accuracy=0.826202
# INFO:root:Epoch[0] Train-accuracy=0.833239
# INFO:root:Epoch[0] Time cost=0.114
# INFO:root:Epoch[0] Validation-accuracy=0.841797
# INFO:root:Epoch[1] Batch [64]	Speed: 65499.27 samples/sec	accuracy=0.845913
# INFO:root:Epoch[1] Train-accuracy=0.833239
# INFO:root:Epoch[1] Time cost=0.114
# INFO:root:Epoch[1] Validation-accuracy=0.841797
# INFO:root:Epoch[2] Batch [64]	Speed: 67926.10 samples/sec	accuracy=0.845913
# INFO:root:Epoch[2] Train-accuracy=0.833239
# INFO:root:Epoch[2] Time cost=0.111
# INFO:root:Epoch[2] Validation-accuracy=0.841797
# INFO:root:Epoch[3] Batch [64]	Speed: 65015.66 samples/sec	accuracy=0.845913
# INFO:root:Epoch[3] Train-accuracy=0.833239
# INFO:root:Epoch[3] Time cost=0.117
# INFO:root:Epoch[3] Validation-accuracy=0.841797
# INFO:root:Epoch[4] Batch [64]	Speed: 70738.35 samples/sec	accuracy=0.845913
# INFO:root:Epoch[4] Train-accuracy=0.833239
# INFO:root:Epoch[4] Time cost=0.109
# INFO:root:Epoch[4] Validation-accuracy=0.841797
# INFO:root:Epoch[5] Batch [64]	Speed: 67156.08 samples/sec	accuracy=0.845913
# INFO:root:Epoch[5] Train-accuracy=0.833239
# INFO:root:Epoch[5] Time cost=0.119
# INFO:root:Epoch[5] Validation-accuracy=0.841797
# INFO:root:Epoch[6] Batch [64]	Speed: 81189.54 samples/sec	accuracy=0.845913
# INFO:root:Epoch[6] Train-accuracy=0.833239
# INFO:root:Epoch[6] Time cost=0.096
# INFO:root:Epoch[6] Validation-accuracy=0.841797
# INFO:root:Epoch[7] Batch [64]	Speed: 98449.15 samples/sec	accuracy=0.845913
# INFO:root:Epoch[7] Train-accuracy=0.833239
# INFO:root:Epoch[7] Time cost=0.087
# INFO:root:Epoch[7] Validation-accuracy=0.841797
# INFO:root:Epoch[8] Batch [64]	Speed: 81422.34 samples/sec	accuracy=0.845913
# INFO:root:Epoch[8] Train-accuracy=0.833239
# INFO:root:Epoch[8] Time cost=0.096
# INFO:root:Epoch[8] Validation-accuracy=0.841797
# INFO:root:Epoch[9] Batch [64]	Speed: 86776.66 samples/sec	accuracy=0.845913
# INFO:root:Epoch[9] Train-accuracy=0.833239
# INFO:root:Epoch[9] Time cost=0.093
# INFO:root:Epoch[9] Validation-accuracy=0.841797
# INFO:root:Epoch[10] Batch [64]	Speed: 85913.09 samples/sec	accuracy=0.845913
# INFO:root:Epoch[10] Train-accuracy=0.833239
# INFO:root:Epoch[10] Time cost=0.092
# INFO:root:Epoch[10] Validation-accuracy=0.841797
# INFO:root:Epoch[11] Batch [64]	Speed: 81928.67 samples/sec	accuracy=0.845913
# INFO:root:Epoch[11] Train-accuracy=0.833239
# INFO:root:Epoch[11] Time cost=0.095
# INFO:root:Epoch[11] Validation-accuracy=0.841797
# INFO:root:Epoch[12] Batch [64]	Speed: 84114.44 samples/sec	accuracy=0.845913
# INFO:root:Epoch[12] Train-accuracy=0.833239
# INFO:root:Epoch[12] Time cost=0.095
# INFO:root:Epoch[12] Validation-accuracy=0.841797
# INFO:root:Epoch[13] Batch [64]	Speed: 82141.38 samples/sec	accuracy=0.845913
# INFO:root:Epoch[13] Train-accuracy=0.833523
# INFO:root:Epoch[13] Time cost=0.095
# INFO:root:Epoch[13] Validation-accuracy=0.841406
# INFO:root:Epoch[14] Batch [64]	Speed: 86606.49 samples/sec	accuracy=0.855288
# INFO:root:Epoch[14] Train-accuracy=0.855966
# INFO:root:Epoch[14] Time cost=0.095
# INFO:root:Epoch[14] Validation-accuracy=0.840625
# INFO:root:Epoch[15] Batch [64]	Speed: 83479.28 samples/sec	accuracy=0.877644
# INFO:root:Epoch[15] Train-accuracy=0.879830
# INFO:root:Epoch[15] Time cost=0.095
# INFO:root:Epoch[15] Validation-accuracy=0.835547
# INFO:root:Epoch[16] Batch [64]	Speed: 86041.31 samples/sec	accuracy=0.901202
# INFO:root:Epoch[16] Train-accuracy=0.906534
# INFO:root:Epoch[16] Time cost=0.094
# INFO:root:Epoch[16] Validation-accuracy=0.833203
# INFO:root:Epoch[17] Batch [64]	Speed: 82530.06 samples/sec	accuracy=0.927163
# INFO:root:Epoch[17] Train-accuracy=0.940057
# INFO:root:Epoch[17] Time cost=0.097
# INFO:root:Epoch[17] Validation-accuracy=0.821875
# INFO:root:Epoch[18] Batch [64]	Speed: 90255.05 samples/sec	accuracy=0.957212
# INFO:root:Epoch[18] Train-accuracy=0.972727
# INFO:root:Epoch[18] Time cost=0.095
# INFO:root:Epoch[18] Validation-accuracy=0.816406
# INFO:root:Epoch[19] Batch [64]	Speed: 81240.99 samples/sec	accuracy=0.982933
# INFO:root:Epoch[19] Train-accuracy=0.990341
# INFO:root:Epoch[19] Time cost=0.097
# INFO:root:Epoch[19] Validation-accuracy=0.809375
# INFO:root:Epoch[20] Batch [64]	Speed: 69417.54 samples/sec	accuracy=0.993990
# INFO:root:Epoch[20] Train-accuracy=0.993750
# INFO:root:Epoch[20] Time cost=0.105
# INFO:root:Epoch[20] Validation-accuracy=0.814453
# INFO:root:Epoch[21] Batch [64]	Speed: 82708.06 samples/sec	accuracy=0.995673
# INFO:root:Epoch[21] Train-accuracy=0.996591
# INFO:root:Epoch[21] Time cost=0.096
# INFO:root:Epoch[21] Validation-accuracy=0.825781
# INFO:root:Epoch[22] Batch [64]	Speed: 76129.63 samples/sec	accuracy=0.996635
# INFO:root:Epoch[22] Train-accuracy=0.998295
# INFO:root:Epoch[22] Time cost=0.102
# INFO:root:Epoch[22] Validation-accuracy=0.827734
# INFO:root:Epoch[23] Batch [64]	Speed: 72004.31 samples/sec	accuracy=0.998317
# INFO:root:Epoch[23] Train-accuracy=0.999148
# INFO:root:Epoch[23] Time cost=0.104
# INFO:root:Epoch[23] Validation-accuracy=0.824219
# INFO:root:Epoch[24] Batch [64]	Speed: 82861.64 samples/sec	accuracy=0.998077
# INFO:root:Epoch[24] Train-accuracy=1.000000
# INFO:root:Epoch[24] Time cost=0.097
# INFO:root:Epoch[24] Validation-accuracy=0.787500
# INFO:root:Epoch[25] Batch [64]	Speed: 79225.76 samples/sec	accuracy=0.999038
# INFO:root:Epoch[25] Train-accuracy=0.999716
# INFO:root:Epoch[25] Time cost=0.099
# INFO:root:Epoch[25] Validation-accuracy=0.785156
# INFO:root:Epoch[26] Batch [64]	Speed: 82892.42 samples/sec	accuracy=0.999038
# INFO:root:Epoch[26] Train-accuracy=1.000000
# INFO:root:Epoch[26] Time cost=0.097
# INFO:root:Epoch[26] Validation-accuracy=0.830469
# INFO:root:Epoch[27] Batch [64]	Speed: 75871.76 samples/sec	accuracy=0.999760
# INFO:root:Epoch[27] Train-accuracy=1.000000
# INFO:root:Epoch[27] Time cost=0.101
# INFO:root:Epoch[27] Validation-accuracy=0.828516
# INFO:root:Epoch[28] Batch [64]	Speed: 84124.32 samples/sec	accuracy=1.000000
# INFO:root:Epoch[28] Train-accuracy=0.999716
# INFO:root:Epoch[28] Time cost=0.096
# INFO:root:Epoch[28] Validation-accuracy=0.806250
# INFO:root:Epoch[29] Batch [64]	Speed: 82654.73 samples/sec	accuracy=1.000000
# INFO:root:Epoch[29] Train-accuracy=1.000000
# INFO:root:Epoch[29] Time cost=0.096
# INFO:root:Epoch[29] Validation-accuracy=0.808594
# INFO:root:Epoch[30] Batch [64]	Speed: 83418.48 samples/sec	accuracy=1.000000
# INFO:root:Epoch[30] Train-accuracy=1.000000
# INFO:root:Epoch[30] Time cost=0.093
# INFO:root:Epoch[30] Validation-accuracy=0.817187
# INFO:root:Epoch[31] Batch [64]	Speed: 83225.72 samples/sec	accuracy=1.000000
# INFO:root:Epoch[31] Train-accuracy=1.000000
# INFO:root:Epoch[31] Time cost=0.097
# INFO:root:Epoch[31] Validation-accuracy=0.822266
# INFO:root:Epoch[32] Batch [64]	Speed: 72048.70 samples/sec	accuracy=1.000000
# INFO:root:Epoch[32] Train-accuracy=1.000000
# INFO:root:Epoch[32] Time cost=0.104
# INFO:root:Epoch[32] Validation-accuracy=0.825391
# INFO:root:Epoch[33] Batch [64]	Speed: 73112.05 samples/sec	accuracy=1.000000
# INFO:root:Epoch[33] Train-accuracy=1.000000
# INFO:root:Epoch[33] Time cost=0.103
# INFO:root:Epoch[33] Validation-accuracy=0.822266
# INFO:root:Epoch[34] Batch [64]	Speed: 84878.68 samples/sec	accuracy=1.000000
# INFO:root:Epoch[34] Train-accuracy=1.000000
# INFO:root:Epoch[34] Time cost=0.096
# INFO:root:Epoch[34] Validation-accuracy=0.816406
# INFO:root:Epoch[35] Batch [64]	Speed: 82692.53 samples/sec	accuracy=1.000000
# INFO:root:Epoch[35] Train-accuracy=1.000000
# INFO:root:Epoch[35] Time cost=0.095
# INFO:root:Epoch[35] Validation-accuracy=0.816016
# INFO:root:Epoch[36] Batch [64]	Speed: 78555.94 samples/sec	accuracy=1.000000
# INFO:root:Epoch[36] Train-accuracy=1.000000
# INFO:root:Epoch[36] Time cost=0.096
# INFO:root:Epoch[36] Validation-accuracy=0.816797
# INFO:root:Epoch[37] Batch [64]	Speed: 82382.44 samples/sec	accuracy=1.000000
# INFO:root:Epoch[37] Train-accuracy=1.000000
# INFO:root:Epoch[37] Time cost=0.094
# INFO:root:Epoch[37] Validation-accuracy=0.814453
# INFO:root:Epoch[38] Batch [64]	Speed: 83467.93 samples/sec	accuracy=1.000000
# INFO:root:Epoch[38] Train-accuracy=1.000000
# INFO:root:Epoch[38] Time cost=0.098
# INFO:root:Epoch[38] Validation-accuracy=0.811328
# INFO:root:Epoch[39] Batch [64]	Speed: 77747.87 samples/sec	accuracy=1.000000
# INFO:root:Epoch[39] Train-accuracy=1.000000
# INFO:root:Epoch[39] Time cost=0.099
# INFO:root:Epoch[39] Validation-accuracy=0.812500
# INFO:root:Epoch[40] Batch [64]	Speed: 74982.63 samples/sec	accuracy=1.000000
# INFO:root:Epoch[40] Train-accuracy=1.000000
# INFO:root:Epoch[40] Time cost=0.101
# INFO:root:Epoch[40] Validation-accuracy=0.813672
# INFO:root:Epoch[41] Batch [64]	Speed: 81803.84 samples/sec	accuracy=1.000000
# INFO:root:Epoch[41] Train-accuracy=1.000000
# INFO:root:Epoch[41] Time cost=0.097
# INFO:root:Epoch[41] Validation-accuracy=0.814453
# INFO:root:Epoch[42] Batch [64]	Speed: 85921.69 samples/sec	accuracy=1.000000
# INFO:root:Epoch[42] Train-accuracy=1.000000
# INFO:root:Epoch[42] Time cost=0.093
# INFO:root:Epoch[42] Validation-accuracy=0.813672
# INFO:root:Epoch[43] Batch [64]	Speed: 86390.48 samples/sec	accuracy=1.000000
# INFO:root:Epoch[43] Train-accuracy=1.000000
# INFO:root:Epoch[43] Time cost=0.090
# INFO:root:Epoch[43] Validation-accuracy=0.813672
# INFO:root:Epoch[44] Batch [64]	Speed: 68541.00 samples/sec	accuracy=1.000000
# INFO:root:Epoch[44] Train-accuracy=1.000000
# INFO:root:Epoch[44] Time cost=0.132
# INFO:root:Epoch[44] Validation-accuracy=0.812891
# INFO:root:Epoch[45] Batch [64]	Speed: 56164.65 samples/sec	accuracy=1.000000
# INFO:root:Epoch[45] Train-accuracy=1.000000
# INFO:root:Epoch[45] Time cost=0.134
# INFO:root:Epoch[45] Validation-accuracy=0.813281
# INFO:root:Epoch[46] Batch [64]	Speed: 79068.24 samples/sec	accuracy=1.000000
# INFO:root:Epoch[46] Train-accuracy=1.000000
# INFO:root:Epoch[46] Time cost=0.098
# INFO:root:Epoch[46] Validation-accuracy=0.812891
# INFO:root:Epoch[47] Batch [64]	Speed: 83969.72 samples/sec	accuracy=1.000000
# INFO:root:Epoch[47] Train-accuracy=1.000000
# INFO:root:Epoch[47] Time cost=0.090
# INFO:root:Epoch[47] Validation-accuracy=0.813281
# INFO:root:Epoch[48] Batch [64]	Speed: 84311.34 samples/sec	accuracy=1.000000
# INFO:root:Epoch[48] Train-accuracy=1.000000
# INFO:root:Epoch[48] Time cost=0.094
# INFO:root:Epoch[48] Validation-accuracy=0.813281
# INFO:root:Epoch[49] Batch [64]	Speed: 67416.72 samples/sec	accuracy=1.000000
# INFO:root:Epoch[49] Train-accuracy=1.000000
# INFO:root:Epoch[49] Time cost=0.122
# INFO:root:Epoch[49] Validation-accuracy=0.813672
# INFO:root:Epoch[50] Batch [64]	Speed: 55788.03 samples/sec	accuracy=1.000000
# INFO:root:Epoch[50] Train-accuracy=1.000000
# INFO:root:Epoch[50] Time cost=0.134
# INFO:root:Epoch[50] Validation-accuracy=0.813672
# INFO:root:Epoch[51] Batch [64]	Speed: 78506.40 samples/sec	accuracy=1.000000
# INFO:root:Epoch[51] Train-accuracy=1.000000
# INFO:root:Epoch[51] Time cost=0.095
# INFO:root:Epoch[51] Validation-accuracy=0.813281
# INFO:root:Epoch[52] Batch [64]	Speed: 82797.34 samples/sec	accuracy=1.000000
# INFO:root:Epoch[52] Train-accuracy=1.000000
# INFO:root:Epoch[52] Time cost=0.096
# INFO:root:Epoch[52] Validation-accuracy=0.813281
# INFO:root:Epoch[53] Batch [64]	Speed: 81848.27 samples/sec	accuracy=1.000000
# INFO:root:Epoch[53] Train-accuracy=1.000000
# INFO:root:Epoch[53] Time cost=0.097
# INFO:root:Epoch[53] Validation-accuracy=0.813672
# INFO:root:Epoch[54] Batch [64]	Speed: 82404.96 samples/sec	accuracy=1.000000
# INFO:root:Epoch[54] Train-accuracy=1.000000
# INFO:root:Epoch[54] Time cost=0.096
# INFO:root:Epoch[54] Validation-accuracy=0.814063
# INFO:root:Epoch[55] Batch [64]	Speed: 58834.56 samples/sec	accuracy=1.000000
# INFO:root:Epoch[55] Train-accuracy=1.000000
# INFO:root:Epoch[55] Time cost=0.138
# INFO:root:Epoch[55] Validation-accuracy=0.813281
# INFO:root:Epoch[56] Batch [64]	Speed: 56647.64 samples/sec	accuracy=1.000000
# INFO:root:Epoch[56] Train-accuracy=1.000000
# INFO:root:Epoch[56] Time cost=0.141
# INFO:root:Epoch[56] Validation-accuracy=0.812891
# INFO:root:Epoch[57] Batch [64]	Speed: 79387.58 samples/sec	accuracy=1.000000
# INFO:root:Epoch[57] Train-accuracy=1.000000
# INFO:root:Epoch[57] Time cost=0.098
# INFO:root:Epoch[57] Validation-accuracy=0.812891
# INFO:root:Epoch[58] Batch [64]	Speed: 80932.90 samples/sec	accuracy=1.000000
# INFO:root:Epoch[58] Train-accuracy=1.000000
# INFO:root:Epoch[58] Time cost=0.095
# INFO:root:Epoch[58] Validation-accuracy=0.812500
# INFO:root:Epoch[59] Batch [64]	Speed: 78226.86 samples/sec	accuracy=1.000000
# INFO:root:Epoch[59] Train-accuracy=1.000000
# INFO:root:Epoch[59] Time cost=0.101
# INFO:root:Epoch[59] Validation-accuracy=0.812500
# INFO:root:Epoch[60] Batch [64]	Speed: 83915.99 samples/sec	accuracy=1.000000
# INFO:root:Epoch[60] Train-accuracy=1.000000
# INFO:root:Epoch[60] Time cost=0.096
# INFO:root:Epoch[60] Validation-accuracy=0.812500
# INFO:root:Epoch[61] Batch [64]	Speed: 81860.75 samples/sec	accuracy=1.000000
# INFO:root:Epoch[61] Train-accuracy=1.000000
# INFO:root:Epoch[61] Time cost=0.097
# INFO:root:Epoch[61] Validation-accuracy=0.812891
# INFO:root:Epoch[62] Batch [64]	Speed: 80788.28 samples/sec	accuracy=1.000000
# INFO:root:Epoch[62] Train-accuracy=1.000000
# INFO:root:Epoch[62] Time cost=0.096
# INFO:root:Epoch[62] Validation-accuracy=0.812500
# INFO:root:Epoch[63] Batch [64]	Speed: 80651.36 samples/sec	accuracy=1.000000
# INFO:root:Epoch[63] Train-accuracy=1.000000
# INFO:root:Epoch[63] Time cost=0.093
# INFO:root:Epoch[63] Validation-accuracy=0.812891
# INFO:root:Epoch[64] Batch [64]	Speed: 64893.12 samples/sec	accuracy=1.000000
# INFO:root:Epoch[64] Train-accuracy=1.000000
# INFO:root:Epoch[64] Time cost=0.130
# INFO:root:Epoch[64] Validation-accuracy=0.812891
# INFO:root:Epoch[65] Batch [64]	Speed: 64953.23 samples/sec	accuracy=1.000000
# INFO:root:Epoch[65] Train-accuracy=1.000000
# INFO:root:Epoch[65] Time cost=0.111
# INFO:root:Epoch[65] Validation-accuracy=0.812891
# INFO:root:Epoch[66] Batch [64]	Speed: 80021.75 samples/sec	accuracy=1.000000
# INFO:root:Epoch[66] Train-accuracy=1.000000
# INFO:root:Epoch[66] Time cost=0.099
# INFO:root:Epoch[66] Validation-accuracy=0.813672
# INFO:root:Epoch[67] Batch [64]	Speed: 82203.87 samples/sec	accuracy=1.000000
# INFO:root:Epoch[67] Train-accuracy=1.000000
# INFO:root:Epoch[67] Time cost=0.100
# INFO:root:Epoch[67] Validation-accuracy=0.812500
# INFO:root:Epoch[68] Batch [64]	Speed: 75941.51 samples/sec	accuracy=1.000000
# INFO:root:Epoch[68] Train-accuracy=1.000000
# INFO:root:Epoch[68] Time cost=0.102
# INFO:root:Epoch[68] Validation-accuracy=0.812891
# INFO:root:Epoch[69] Batch [64]	Speed: 80019.14 samples/sec	accuracy=1.000000
# INFO:root:Epoch[69] Train-accuracy=1.000000
# INFO:root:Epoch[69] Time cost=0.099
# INFO:root:Epoch[69] Validation-accuracy=0.814063
# INFO:root:Epoch[70] Batch [64]	Speed: 81221.78 samples/sec	accuracy=1.000000
# INFO:root:Epoch[70] Train-accuracy=1.000000
# INFO:root:Epoch[70] Time cost=0.100
# INFO:root:Epoch[70] Validation-accuracy=0.813672
# INFO:root:Epoch[71] Batch [64]	Speed: 72382.92 samples/sec	accuracy=1.000000
# INFO:root:Epoch[71] Train-accuracy=1.000000
# INFO:root:Epoch[71] Time cost=0.113
# INFO:root:Epoch[71] Validation-accuracy=0.814063
# INFO:root:Epoch[72] Batch [64]	Speed: 58798.52 samples/sec	accuracy=1.000000
# INFO:root:Epoch[72] Train-accuracy=1.000000
# INFO:root:Epoch[72] Time cost=0.117
# INFO:root:Epoch[72] Validation-accuracy=0.814063
# INFO:root:Epoch[73] Batch [64]	Speed: 80501.71 samples/sec	accuracy=1.000000
# INFO:root:Epoch[73] Train-accuracy=1.000000
# INFO:root:Epoch[73] Time cost=0.097
# INFO:root:Epoch[73] Validation-accuracy=0.814063
# INFO:root:Epoch[74] Batch [64]	Speed: 82458.36 samples/sec	accuracy=1.000000
# INFO:root:Epoch[74] Train-accuracy=1.000000
# INFO:root:Epoch[74] Time cost=0.097
# INFO:root:Epoch[74] Validation-accuracy=0.814453
# INFO:root:Epoch[75] Batch [64]	Speed: 82173.99 samples/sec	accuracy=1.000000
# INFO:root:Epoch[75] Train-accuracy=1.000000
# INFO:root:Epoch[75] Time cost=0.099
# INFO:root:Epoch[75] Validation-accuracy=0.813672
# INFO:root:Epoch[76] Batch [64]	Speed: 76605.56 samples/sec	accuracy=1.000000
# INFO:root:Epoch[76] Train-accuracy=1.000000
# INFO:root:Epoch[76] Time cost=0.103
# INFO:root:Epoch[76] Validation-accuracy=0.814063
# INFO:root:Epoch[77] Batch [64]	Speed: 65918.72 samples/sec	accuracy=1.000000
# INFO:root:Epoch[77] Train-accuracy=1.000000
# INFO:root:Epoch[77] Time cost=0.130
# INFO:root:Epoch[77] Validation-accuracy=0.814453
# INFO:root:Epoch[78] Batch [64]	Speed: 64521.94 samples/sec	accuracy=1.000000
# INFO:root:Epoch[78] Train-accuracy=1.000000
# INFO:root:Epoch[78] Time cost=0.120
# INFO:root:Epoch[78] Validation-accuracy=0.814844
# INFO:root:Epoch[79] Batch [64]	Speed: 70367.19 samples/sec	accuracy=1.000000
# INFO:root:Epoch[79] Train-accuracy=1.000000
# INFO:root:Epoch[79] Time cost=0.107
# INFO:root:Epoch[79] Validation-accuracy=0.814063
# INFO:root:Epoch[80] Batch [64]	Speed: 82333.88 samples/sec	accuracy=1.000000
# INFO:root:Epoch[80] Train-accuracy=1.000000
# INFO:root:Epoch[80] Time cost=0.094
# INFO:root:Epoch[80] Validation-accuracy=0.814844
# INFO:root:Epoch[81] Batch [64]	Speed: 81869.72 samples/sec	accuracy=1.000000
# INFO:root:Epoch[81] Train-accuracy=1.000000
# INFO:root:Epoch[81] Time cost=0.095
# INFO:root:Epoch[81] Validation-accuracy=0.814844
# INFO:root:Epoch[82] Batch [64]	Speed: 83386.49 samples/sec	accuracy=1.000000
# INFO:root:Epoch[82] Train-accuracy=1.000000
# INFO:root:Epoch[82] Time cost=0.096
# INFO:root:Epoch[82] Validation-accuracy=0.814844
# INFO:root:Epoch[83] Batch [64]	Speed: 84363.09 samples/sec	accuracy=1.000000
# INFO:root:Epoch[83] Train-accuracy=1.000000
# INFO:root:Epoch[83] Time cost=0.096
# INFO:root:Epoch[83] Validation-accuracy=0.815234
# INFO:root:Epoch[84] Batch [64]	Speed: 81948.99 samples/sec	accuracy=1.000000
# INFO:root:Epoch[84] Train-accuracy=1.000000
# INFO:root:Epoch[84] Time cost=0.094
# INFO:root:Epoch[84] Validation-accuracy=0.814844
# INFO:root:Epoch[85] Batch [64]	Speed: 81402.66 samples/sec	accuracy=1.000000
# INFO:root:Epoch[85] Train-accuracy=1.000000
# INFO:root:Epoch[85] Time cost=0.102
# INFO:root:Epoch[85] Validation-accuracy=0.815234
# INFO:root:Epoch[86] Batch [64]	Speed: 64039.95 samples/sec	accuracy=1.000000
# INFO:root:Epoch[86] Train-accuracy=1.000000
# INFO:root:Epoch[86] Time cost=0.135
# INFO:root:Epoch[86] Validation-accuracy=0.815234
# INFO:root:Epoch[87] Batch [64]	Speed: 50815.69 samples/sec	accuracy=1.000000
# INFO:root:Epoch[87] Train-accuracy=1.000000
# INFO:root:Epoch[87] Time cost=0.154
# INFO:root:Epoch[87] Validation-accuracy=0.814844
# INFO:root:Epoch[88] Batch [64]	Speed: 46471.14 samples/sec	accuracy=1.000000
# INFO:root:Epoch[88] Train-accuracy=1.000000
# INFO:root:Epoch[88] Time cost=0.160
# INFO:root:Epoch[88] Validation-accuracy=0.815234
# INFO:root:Epoch[89] Batch [64]	Speed: 56902.43 samples/sec	accuracy=1.000000
# INFO:root:Epoch[89] Train-accuracy=1.000000
# INFO:root:Epoch[89] Time cost=0.118
# INFO:root:Epoch[89] Validation-accuracy=0.815234
# INFO:root:Epoch[90] Batch [64]	Speed: 81682.49 samples/sec	accuracy=1.000000
# INFO:root:Epoch[90] Train-accuracy=1.000000
# INFO:root:Epoch[90] Time cost=0.097
# INFO:root:Epoch[90] Validation-accuracy=0.815625
# INFO:root:Epoch[91] Batch [64]	Speed: 61394.61 samples/sec	accuracy=1.000000
# INFO:root:Epoch[91] Train-accuracy=1.000000
# INFO:root:Epoch[91] Time cost=0.132
# INFO:root:Epoch[91] Validation-accuracy=0.816016
# INFO:root:Epoch[92] Batch [64]	Speed: 56089.66 samples/sec	accuracy=1.000000
# INFO:root:Epoch[92] Train-accuracy=1.000000
# INFO:root:Epoch[92] Time cost=0.149
# INFO:root:Epoch[92] Validation-accuracy=0.816016
# INFO:root:Epoch[93] Batch [64]	Speed: 54783.62 samples/sec	accuracy=1.000000
# INFO:root:Epoch[93] Train-accuracy=1.000000
# INFO:root:Epoch[93] Time cost=0.141
# INFO:root:Epoch[93] Validation-accuracy=0.814453
# INFO:root:Epoch[94] Batch [64]	Speed: 55741.70 samples/sec	accuracy=1.000000
# INFO:root:Epoch[94] Train-accuracy=1.000000
# INFO:root:Epoch[94] Time cost=0.131
# INFO:root:Epoch[94] Validation-accuracy=0.813672
# INFO:root:Epoch[95] Batch [64]	Speed: 88719.75 samples/sec	accuracy=1.000000
# INFO:root:Epoch[95] Train-accuracy=1.000000
# INFO:root:Epoch[95] Time cost=0.093
# INFO:root:Epoch[95] Validation-accuracy=0.816797
# INFO:root:Epoch[96] Batch [64]	Speed: 83877.48 samples/sec	accuracy=1.000000
# INFO:root:Epoch[96] Train-accuracy=1.000000
# INFO:root:Epoch[96] Time cost=0.096
# INFO:root:Epoch[96] Validation-accuracy=0.815625
# INFO:root:Epoch[97] Batch [64]	Speed: 80219.41 samples/sec	accuracy=1.000000
# INFO:root:Epoch[97] Train-accuracy=1.000000
# INFO:root:Epoch[97] Time cost=0.100
# INFO:root:Epoch[97] Validation-accuracy=0.815625
# INFO:root:Epoch[98] Batch [64]	Speed: 80057.17 samples/sec	accuracy=1.000000
# INFO:root:Epoch[98] Train-accuracy=1.000000
# INFO:root:Epoch[98] Time cost=0.097
# INFO:root:Epoch[98] Validation-accuracy=0.815234
# INFO:root:Epoch[99] Batch [64]	Speed: 78458.71 samples/sec	accuracy=1.000000
# INFO:root:Epoch[99] Train-accuracy=1.000000
# INFO:root:Epoch[99] Time cost=0.096
# INFO:root:Epoch[99] Validation-accuracy=0.816016
# Accuracy: 81.6015625 %

# %%
# save a model to mymodel-symbol.json and mymodel-0100.params
prefix = 'DNN_SVM'
epoch = 100
mod.save_checkpoint(prefix, epoch)

# load model back
model_loaded = mx.model.FeedForward.load(prefix, epoch)
# Out:
# INFO:root:Saved checkpoint to "DNN_SVM-0100.params"

# %%
prob = model_loaded.predict(val_iters)
logging.info('Finish predict of DNN+SVM')
# Check the accuracy from prediction
val_iters.reset()

y_batch = []
for dbatch in val_iters:
    label = dbatch.label[0].asnumpy()
    pad = val_iters.getpad()
    real_size = label.shape[0] - pad
    y_batch.append(label[0:real_size])
y = np.concatenate(y_batch)

# get prediction label 
py = np.argmax(prob, axis=1)
acc1 = float(np.sum(py == y)) / len(y)
logging.info('Test accuracy = %f', acc1)
cfn_matrix=confusion_matrix(y,py)
print(classification_report (y,py))
print(cfn_matrix)
# Out:
# INFO:root:Finish predict of DNN+SVM
# INFO:root:Test accuracy = 0.815975
#              precision    recall  f1-score   support
#
#         0.0       0.34      0.17      0.22       404
#         1.0       0.86      0.94      0.90      2150
#
# avg / total       0.77      0.82      0.79      2554
#
# [[  67  337]
#  [ 133 2017]]

# %%
# Deeper DNN with dropout + SVM
data = mx.symbol.Variable('data')
data = mx.sym.Flatten(data=data)

fc1  = mx.symbol.FullyConnected(data = data, name='fc1', num_hidden=1024)
act1 = mx.symbol.Activation(data = fc1, name='relu1', act_type="relu")
fc2  = mx.symbol.FullyConnected(data = act1, name = 'fc2', num_hidden = 1024)
act2 = mx.symbol.Activation(data = fc2, name='relu2', act_type="relu")
drop1 = mx.sym.Dropout(data=act2, p=0.5)

fc3  = mx.symbol.FullyConnected(data = drop1, name = 'fc3', num_hidden = 512)
act3 = mx.symbol.Activation(data = fc3, name='relu3', act_type="relu")
fc4  = mx.symbol.FullyConnected(data = act3, name = 'fc4', num_hidden = 512)
act4 = mx.symbol.Activation(data = fc4, name='relu4', act_type="relu")

drop2 = mx.sym.Dropout(data=act4, p=0.5)

fc5  = mx.symbol.FullyConnected(data = drop2, name='fc5', num_hidden=32)

mlp = mx.symbol.SVMOutput(data=fc5, name='svm')

# draw network chart
shape = {"data" : (batch_size, 1, 32, 32)}
mx.viz.plot_network(symbol=mlp, shape=shape)
network_chart=mx.viz.plot_network(symbol=mlp, shape=shape)
network_chart.render('DDNN + SVM')
# Out:
# 'DDNN + SVM.pdf'

# %%
mod = mx.mod.Module(
    context = mx.gpu(0),  # Run on GPU 0
    symbol = mlp,         # Use the network we just defined
    label_names = ['svm_label'],
)
mod.fit(
    train_data=train_iters,
    eval_data=val_iters,  
    batch_end_callback = mx.callback.Speedometer(batch_size, 64),  
    num_epoch = 100,       # Train for 100 epochs
    optimizer_params = {
        'learning_rate': 0.001,  # Learning rate
        'momentum': 0.9,       # Momentum for SGD with momentum
        'wd': 0.00001,         # Weight decay for regularization
    },
)

print('Accuracy:', mod.score(test_iter, mx.metric.Accuracy())[0][1]*100, '%')
# Out:
# INFO:root:Epoch[0] Batch [64]	Speed: 40604.08 samples/sec	accuracy=0.834375
# INFO:root:Epoch[0] Train-accuracy=0.833239
# INFO:root:Epoch[0] Time cost=0.249
# INFO:root:Epoch[0] Validation-accuracy=0.841797
# INFO:root:Epoch[1] Batch [64]	Speed: 37239.71 samples/sec	accuracy=0.845913
# INFO:root:Epoch[1] Train-accuracy=0.833239
# INFO:root:Epoch[1] Time cost=0.206
# INFO:root:Epoch[1] Validation-accuracy=0.841797
# INFO:root:Epoch[2] Batch [64]	Speed: 37487.39 samples/sec	accuracy=0.845913
# INFO:root:Epoch[2] Train-accuracy=0.833239
# INFO:root:Epoch[2] Time cost=0.205
# INFO:root:Epoch[2] Validation-accuracy=0.841797
# INFO:root:Epoch[3] Batch [64]	Speed: 37682.09 samples/sec	accuracy=0.845913
# INFO:root:Epoch[3] Train-accuracy=0.833239
# INFO:root:Epoch[3] Time cost=0.204
# INFO:root:Epoch[3] Validation-accuracy=0.841797
# INFO:root:Epoch[4] Batch [64]	Speed: 37019.12 samples/sec	accuracy=0.845913
# INFO:root:Epoch[4] Train-accuracy=0.833239
# INFO:root:Epoch[4] Time cost=0.209
# INFO:root:Epoch[4] Validation-accuracy=0.841797
# INFO:root:Epoch[5] Batch [64]	Speed: 37096.25 samples/sec	accuracy=0.845913
# INFO:root:Epoch[5] Train-accuracy=0.833239
# INFO:root:Epoch[5] Time cost=0.214
# INFO:root:Epoch[5] Validation-accuracy=0.841797
# INFO:root:Epoch[6] Batch [64]	Speed: 36178.43 samples/sec	accuracy=0.845913
# INFO:root:Epoch[6] Train-accuracy=0.833239
# INFO:root:Epoch[6] Time cost=0.209
# INFO:root:Epoch[6] Validation-accuracy=0.841797
# INFO:root:Epoch[7] Batch [64]	Speed: 38511.16 samples/sec	accuracy=0.845913
# INFO:root:Epoch[7] Train-accuracy=0.833239
# INFO:root:Epoch[7] Time cost=0.202
# INFO:root:Epoch[7] Validation-accuracy=0.841797
# INFO:root:Epoch[8] Batch [64]	Speed: 37314.45 samples/sec	accuracy=0.845913
# INFO:root:Epoch[8] Train-accuracy=0.833239
# INFO:root:Epoch[8] Time cost=0.207
# INFO:root:Epoch[8] Validation-accuracy=0.841797
# INFO:root:Epoch[9] Batch [64]	Speed: 37225.99 samples/sec	accuracy=0.845913
# INFO:root:Epoch[9] Train-accuracy=0.833239
# INFO:root:Epoch[9] Time cost=0.205
# INFO:root:Epoch[9] Validation-accuracy=0.841797
# INFO:root:Epoch[10] Batch [64]	Speed: 38220.29 samples/sec	accuracy=0.845913
# INFO:root:Epoch[10] Train-accuracy=0.833239
# INFO:root:Epoch[10] Time cost=0.202
# INFO:root:Epoch[10] Validation-accuracy=0.841797
# INFO:root:Epoch[11] Batch [64]	Speed: 37982.34 samples/sec	accuracy=0.845913
# INFO:root:Epoch[11] Train-accuracy=0.833239
# INFO:root:Epoch[11] Time cost=0.201
# INFO:root:Epoch[11] Validation-accuracy=0.841797
# INFO:root:Epoch[12] Batch [64]	Speed: 37123.03 samples/sec	accuracy=0.845913
# INFO:root:Epoch[12] Train-accuracy=0.833239
# INFO:root:Epoch[12] Time cost=0.205
# INFO:root:Epoch[12] Validation-accuracy=0.841797
# INFO:root:Epoch[13] Batch [64]	Speed: 38531.20 samples/sec	accuracy=0.845913
# INFO:root:Epoch[13] Train-accuracy=0.833239
# INFO:root:Epoch[13] Time cost=0.202
# INFO:root:Epoch[13] Validation-accuracy=0.841797
# INFO:root:Epoch[14] Batch [64]	Speed: 37672.09 samples/sec	accuracy=0.845913
# INFO:root:Epoch[14] Train-accuracy=0.833239
# INFO:root:Epoch[14] Time cost=0.204
# INFO:root:Epoch[14] Validation-accuracy=0.841797
# INFO:root:Epoch[15] Batch [64]	Speed: 38156.37 samples/sec	accuracy=0.845913
# INFO:root:Epoch[15] Train-accuracy=0.833239
# INFO:root:Epoch[15] Time cost=0.201
# INFO:root:Epoch[15] Validation-accuracy=0.841797
# INFO:root:Epoch[16] Batch [64]	Speed: 35998.16 samples/sec	accuracy=0.845913
# INFO:root:Epoch[16] Train-accuracy=0.833239
# INFO:root:Epoch[16] Time cost=0.211
# INFO:root:Epoch[16] Validation-accuracy=0.841797
# INFO:root:Epoch[17] Batch [64]	Speed: 38256.30 samples/sec	accuracy=0.845913
# INFO:root:Epoch[17] Train-accuracy=0.833239
# INFO:root:Epoch[17] Time cost=0.202
# INFO:root:Epoch[17] Validation-accuracy=0.841797
# INFO:root:Epoch[18] Batch [64]	Speed: 38020.59 samples/sec	accuracy=0.845913
# INFO:root:Epoch[18] Train-accuracy=0.833239
# INFO:root:Epoch[18] Time cost=0.202
# INFO:root:Epoch[18] Validation-accuracy=0.841797
# INFO:root:Epoch[19] Batch [64]	Speed: 38239.61 samples/sec	accuracy=0.845913
# INFO:root:Epoch[19] Train-accuracy=0.833239
# INFO:root:Epoch[19] Time cost=0.203
# INFO:root:Epoch[19] Validation-accuracy=0.841797
# INFO:root:Epoch[20] Batch [64]	Speed: 35666.19 samples/sec	accuracy=0.845913
# INFO:root:Epoch[20] Train-accuracy=0.833239
# INFO:root:Epoch[20] Time cost=0.210
# INFO:root:Epoch[20] Validation-accuracy=0.841797
# INFO:root:Epoch[21] Batch [64]	Speed: 35386.80 samples/sec	accuracy=0.845913
# INFO:root:Epoch[21] Train-accuracy=0.833239
# INFO:root:Epoch[21] Time cost=0.212
# INFO:root:Epoch[21] Validation-accuracy=0.841797
# INFO:root:Epoch[22] Batch [64]	Speed: 28011.22 samples/sec	accuracy=0.845913
# INFO:root:Epoch[22] Train-accuracy=0.833239
# INFO:root:Epoch[22] Time cost=0.266
# INFO:root:Epoch[22] Validation-accuracy=0.841797
# INFO:root:Epoch[23] Batch [64]	Speed: 35096.05 samples/sec	accuracy=0.845913
# INFO:root:Epoch[23] Train-accuracy=0.833239
# INFO:root:Epoch[23] Time cost=0.211
# INFO:root:Epoch[23] Validation-accuracy=0.841797
# INFO:root:Epoch[24] Batch [64]	Speed: 37920.39 samples/sec	accuracy=0.845913
# INFO:root:Epoch[24] Train-accuracy=0.833239
# INFO:root:Epoch[24] Time cost=0.211
# INFO:root:Epoch[24] Validation-accuracy=0.841797
# INFO:root:Epoch[25] Batch [64]	Speed: 37281.97 samples/sec	accuracy=0.845913
# INFO:root:Epoch[25] Train-accuracy=0.833239
# INFO:root:Epoch[25] Time cost=0.207
# INFO:root:Epoch[25] Validation-accuracy=0.841797
# INFO:root:Epoch[26] Batch [64]	Speed: 28969.06 samples/sec	accuracy=0.845913
# INFO:root:Epoch[26] Train-accuracy=0.833239
# INFO:root:Epoch[26] Time cost=0.285
# INFO:root:Epoch[26] Validation-accuracy=0.841797
# INFO:root:Epoch[27] Batch [64]	Speed: 23632.87 samples/sec	accuracy=0.845913
# INFO:root:Epoch[27] Train-accuracy=0.833239
# INFO:root:Epoch[27] Time cost=0.289
# INFO:root:Epoch[27] Validation-accuracy=0.841797
# INFO:root:Epoch[28] Batch [64]	Speed: 37668.71 samples/sec	accuracy=0.845913
# INFO:root:Epoch[28] Train-accuracy=0.833239
# INFO:root:Epoch[28] Time cost=0.202
# INFO:root:Epoch[28] Validation-accuracy=0.841797
# INFO:root:Epoch[29] Batch [64]	Speed: 36464.54 samples/sec	accuracy=0.845913
# INFO:root:Epoch[29] Train-accuracy=0.833239
# INFO:root:Epoch[29] Time cost=0.205
# INFO:root:Epoch[29] Validation-accuracy=0.841797
# INFO:root:Epoch[30] Batch [64]	Speed: 38298.60 samples/sec	accuracy=0.845913
# INFO:root:Epoch[30] Train-accuracy=0.833239
# INFO:root:Epoch[30] Time cost=0.205
# INFO:root:Epoch[30] Validation-accuracy=0.841797
# INFO:root:Epoch[31] Batch [64]	Speed: 38515.05 samples/sec	accuracy=0.845913
# INFO:root:Epoch[31] Train-accuracy=0.833239
# INFO:root:Epoch[31] Time cost=0.200
# INFO:root:Epoch[31] Validation-accuracy=0.841797
# INFO:root:Epoch[32] Batch [64]	Speed: 37306.99 samples/sec	accuracy=0.845913
# INFO:root:Epoch[32] Train-accuracy=0.833239
# INFO:root:Epoch[32] Time cost=0.214
# INFO:root:Epoch[32] Validation-accuracy=0.841797
# INFO:root:Epoch[33] Batch [64]	Speed: 24793.58 samples/sec	accuracy=0.845913
# INFO:root:Epoch[33] Train-accuracy=0.833239
# INFO:root:Epoch[33] Time cost=0.259
# INFO:root:Epoch[33] Validation-accuracy=0.841797
# INFO:root:Epoch[34] Batch [64]	Speed: 40083.78 samples/sec	accuracy=0.845913
# INFO:root:Epoch[34] Train-accuracy=0.833239
# INFO:root:Epoch[34] Time cost=0.193
# INFO:root:Epoch[34] Validation-accuracy=0.841797
# INFO:root:Epoch[35] Batch [64]	Speed: 28242.10 samples/sec	accuracy=0.845913
# INFO:root:Epoch[35] Train-accuracy=0.833239
# INFO:root:Epoch[35] Time cost=0.265
# INFO:root:Epoch[35] Validation-accuracy=0.841797
# INFO:root:Epoch[36] Batch [64]	Speed: 31275.70 samples/sec	accuracy=0.845913
# INFO:root:Epoch[36] Train-accuracy=0.833239
# INFO:root:Epoch[36] Time cost=0.250
# INFO:root:Epoch[36] Validation-accuracy=0.841797
# INFO:root:Epoch[37] Batch [64]	Speed: 28765.77 samples/sec	accuracy=0.845913
# INFO:root:Epoch[37] Train-accuracy=0.833239
# INFO:root:Epoch[37] Time cost=0.258
# INFO:root:Epoch[37] Validation-accuracy=0.841797
# INFO:root:Epoch[38] Batch [64]	Speed: 39674.36 samples/sec	accuracy=0.845913
# INFO:root:Epoch[38] Train-accuracy=0.833239
# INFO:root:Epoch[38] Time cost=0.195
# INFO:root:Epoch[38] Validation-accuracy=0.841797
# INFO:root:Epoch[39] Batch [64]	Speed: 34488.52 samples/sec	accuracy=0.845913
# INFO:root:Epoch[39] Train-accuracy=0.833239
# INFO:root:Epoch[39] Time cost=0.243
# INFO:root:Epoch[39] Validation-accuracy=0.841797
# INFO:root:Epoch[40] Batch [64]	Speed: 34716.06 samples/sec	accuracy=0.845913
# INFO:root:Epoch[40] Train-accuracy=0.833239
# INFO:root:Epoch[40] Time cost=0.232
# INFO:root:Epoch[40] Validation-accuracy=0.841797
# INFO:root:Epoch[41] Batch [64]	Speed: 29701.12 samples/sec	accuracy=0.845913
# INFO:root:Epoch[41] Train-accuracy=0.833239
# INFO:root:Epoch[41] Time cost=0.226
# INFO:root:Epoch[41] Validation-accuracy=0.841797
# INFO:root:Epoch[42] Batch [64]	Speed: 40372.59 samples/sec	accuracy=0.845913
# INFO:root:Epoch[42] Train-accuracy=0.833239
# INFO:root:Epoch[42] Time cost=0.202
# INFO:root:Epoch[42] Validation-accuracy=0.841797
# INFO:root:Epoch[43] Batch [64]	Speed: 26484.84 samples/sec	accuracy=0.845913
# INFO:root:Epoch[43] Train-accuracy=0.833239
# INFO:root:Epoch[43] Time cost=0.267
# INFO:root:Epoch[43] Validation-accuracy=0.841797
# INFO:root:Epoch[44] Batch [64]	Speed: 24771.49 samples/sec	accuracy=0.845913
# INFO:root:Epoch[44] Train-accuracy=0.833239
# INFO:root:Epoch[44] Time cost=0.285
# INFO:root:Epoch[44] Validation-accuracy=0.841797
# INFO:root:Epoch[45] Batch [64]	Speed: 37302.05 samples/sec	accuracy=0.845913
# INFO:root:Epoch[45] Train-accuracy=0.833239
# INFO:root:Epoch[45] Time cost=0.203
# INFO:root:Epoch[45] Validation-accuracy=0.841797
# INFO:root:Epoch[46] Batch [64]	Speed: 39996.34 samples/sec	accuracy=0.845913
# INFO:root:Epoch[46] Train-accuracy=0.833239
# INFO:root:Epoch[46] Time cost=0.193
# INFO:root:Epoch[46] Validation-accuracy=0.841797
# INFO:root:Epoch[47] Batch [64]	Speed: 39935.91 samples/sec	accuracy=0.845913
# INFO:root:Epoch[47] Train-accuracy=0.833239
# INFO:root:Epoch[47] Time cost=0.214
# INFO:root:Epoch[47] Validation-accuracy=0.841797
# INFO:root:Epoch[48] Batch [64]	Speed: 25806.14 samples/sec	accuracy=0.845913
# INFO:root:Epoch[48] Train-accuracy=0.833239
# INFO:root:Epoch[48] Time cost=0.278
# INFO:root:Epoch[48] Validation-accuracy=0.841797
# INFO:root:Epoch[49] Batch [64]	Speed: 25945.27 samples/sec	accuracy=0.845913
# INFO:root:Epoch[49] Train-accuracy=0.833239
# INFO:root:Epoch[49] Time cost=0.299
# INFO:root:Epoch[49] Validation-accuracy=0.841797
# INFO:root:Epoch[50] Batch [64]	Speed: 21413.57 samples/sec	accuracy=0.845913
# INFO:root:Epoch[50] Train-accuracy=0.833239
# INFO:root:Epoch[50] Time cost=0.319
# INFO:root:Epoch[50] Validation-accuracy=0.841797
# INFO:root:Epoch[51] Batch [64]	Speed: 21690.08 samples/sec	accuracy=0.845913
# INFO:root:Epoch[51] Train-accuracy=0.833239
# INFO:root:Epoch[51] Time cost=0.317
# INFO:root:Epoch[51] Validation-accuracy=0.841797
# INFO:root:Epoch[52] Batch [64]	Speed: 34188.25 samples/sec	accuracy=0.845913
# INFO:root:Epoch[52] Train-accuracy=0.833239
# INFO:root:Epoch[52] Time cost=0.211
# INFO:root:Epoch[52] Validation-accuracy=0.841797
# INFO:root:Epoch[53] Batch [64]	Speed: 39543.31 samples/sec	accuracy=0.845913
# INFO:root:Epoch[53] Train-accuracy=0.833239
# INFO:root:Epoch[53] Time cost=0.195
# INFO:root:Epoch[53] Validation-accuracy=0.841797
# INFO:root:Epoch[54] Batch [64]	Speed: 39223.98 samples/sec	accuracy=0.845913
# INFO:root:Epoch[54] Train-accuracy=0.833239
# INFO:root:Epoch[54] Time cost=0.235
# INFO:root:Epoch[54] Validation-accuracy=0.841797
# INFO:root:Epoch[55] Batch [64]	Speed: 24737.21 samples/sec	accuracy=0.845913
# INFO:root:Epoch[55] Train-accuracy=0.833239
# INFO:root:Epoch[55] Time cost=0.280
# INFO:root:Epoch[55] Validation-accuracy=0.841797
# INFO:root:Epoch[56] Batch [64]	Speed: 40139.32 samples/sec	accuracy=0.845913
# INFO:root:Epoch[56] Train-accuracy=0.833239
# INFO:root:Epoch[56] Time cost=0.193
# INFO:root:Epoch[56] Validation-accuracy=0.841797
# INFO:root:Epoch[57] Batch [64]	Speed: 38621.55 samples/sec	accuracy=0.845913
# INFO:root:Epoch[57] Train-accuracy=0.833239
# INFO:root:Epoch[57] Time cost=0.228
# INFO:root:Epoch[57] Validation-accuracy=0.841797
# INFO:root:Epoch[58] Batch [64]	Speed: 23989.81 samples/sec	accuracy=0.845913
# INFO:root:Epoch[58] Train-accuracy=0.833239
# INFO:root:Epoch[58] Time cost=0.296
# INFO:root:Epoch[58] Validation-accuracy=0.841797
# INFO:root:Epoch[59] Batch [64]	Speed: 25762.53 samples/sec	accuracy=0.845913
# INFO:root:Epoch[59] Train-accuracy=0.833239
# INFO:root:Epoch[59] Time cost=0.291
# INFO:root:Epoch[59] Validation-accuracy=0.841797
# INFO:root:Epoch[60] Batch [64]	Speed: 32239.66 samples/sec	accuracy=0.845913
# INFO:root:Epoch[60] Train-accuracy=0.833239
# INFO:root:Epoch[60] Time cost=0.221
# INFO:root:Epoch[60] Validation-accuracy=0.841797
# INFO:root:Epoch[61] Batch [64]	Speed: 29307.33 samples/sec	accuracy=0.845913
# INFO:root:Epoch[61] Train-accuracy=0.833239
# INFO:root:Epoch[61] Time cost=0.246
# INFO:root:Epoch[61] Validation-accuracy=0.841797
# INFO:root:Epoch[62] Batch [64]	Speed: 39327.78 samples/sec	accuracy=0.845913
# INFO:root:Epoch[62] Train-accuracy=0.833239
# INFO:root:Epoch[62] Time cost=0.197
# INFO:root:Epoch[62] Validation-accuracy=0.841797
# INFO:root:Epoch[63] Batch [64]	Speed: 39103.55 samples/sec	accuracy=0.845913
# INFO:root:Epoch[63] Train-accuracy=0.833239
# INFO:root:Epoch[63] Time cost=0.199
# INFO:root:Epoch[63] Validation-accuracy=0.841797
# INFO:root:Epoch[64] Batch [64]	Speed: 39340.12 samples/sec	accuracy=0.845913
# INFO:root:Epoch[64] Train-accuracy=0.833239
# INFO:root:Epoch[64] Time cost=0.196
# INFO:root:Epoch[64] Validation-accuracy=0.841797
# INFO:root:Epoch[65] Batch [64]	Speed: 38869.19 samples/sec	accuracy=0.845913
# INFO:root:Epoch[65] Train-accuracy=0.833239
# INFO:root:Epoch[65] Time cost=0.199
# INFO:root:Epoch[65] Validation-accuracy=0.841797
# INFO:root:Epoch[66] Batch [64]	Speed: 39537.22 samples/sec	accuracy=0.845913
# INFO:root:Epoch[66] Train-accuracy=0.833239
# INFO:root:Epoch[66] Time cost=0.195
# INFO:root:Epoch[66] Validation-accuracy=0.841797
# INFO:root:Epoch[67] Batch [64]	Speed: 36732.83 samples/sec	accuracy=0.845913
# INFO:root:Epoch[67] Train-accuracy=0.833239
# INFO:root:Epoch[67] Time cost=0.204
# INFO:root:Epoch[67] Validation-accuracy=0.841797
# INFO:root:Epoch[68] Batch [64]	Speed: 38828.34 samples/sec	accuracy=0.845913
# INFO:root:Epoch[68] Train-accuracy=0.833239
# INFO:root:Epoch[68] Time cost=0.198
# INFO:root:Epoch[68] Validation-accuracy=0.841797
# INFO:root:Epoch[69] Batch [64]	Speed: 39003.94 samples/sec	accuracy=0.845913
# INFO:root:Epoch[69] Train-accuracy=0.833239
# INFO:root:Epoch[69] Time cost=0.198
# INFO:root:Epoch[69] Validation-accuracy=0.841797
# INFO:root:Epoch[70] Batch [64]	Speed: 38469.60 samples/sec	accuracy=0.845913
# INFO:root:Epoch[70] Train-accuracy=0.833239
# INFO:root:Epoch[70] Time cost=0.199
# INFO:root:Epoch[70] Validation-accuracy=0.841797
# INFO:root:Epoch[71] Batch [64]	Speed: 39642.04 samples/sec	accuracy=0.845913
# INFO:root:Epoch[71] Train-accuracy=0.833239
# INFO:root:Epoch[71] Time cost=0.204
# INFO:root:Epoch[71] Validation-accuracy=0.841797
# INFO:root:Epoch[72] Batch [64]	Speed: 39811.44 samples/sec	accuracy=0.845913
# INFO:root:Epoch[72] Train-accuracy=0.833239
# INFO:root:Epoch[72] Time cost=0.196
# INFO:root:Epoch[72] Validation-accuracy=0.841797
# INFO:root:Epoch[73] Batch [64]	Speed: 40195.38 samples/sec	accuracy=0.845913
# INFO:root:Epoch[73] Train-accuracy=0.833239
# INFO:root:Epoch[73] Time cost=0.194
# INFO:root:Epoch[73] Validation-accuracy=0.841797
# INFO:root:Epoch[74] Batch [64]	Speed: 37959.26 samples/sec	accuracy=0.845913
# INFO:root:Epoch[74] Train-accuracy=0.833239
# INFO:root:Epoch[74] Time cost=0.199
# INFO:root:Epoch[74] Validation-accuracy=0.841797
# INFO:root:Epoch[75] Batch [64]	Speed: 39627.04 samples/sec	accuracy=0.845913
# INFO:root:Epoch[75] Train-accuracy=0.833239
# INFO:root:Epoch[75] Time cost=0.194
# INFO:root:Epoch[75] Validation-accuracy=0.841797
# INFO:root:Epoch[76] Batch [64]	Speed: 40376.57 samples/sec	accuracy=0.845913
# INFO:root:Epoch[76] Train-accuracy=0.833239
# INFO:root:Epoch[76] Time cost=0.191
# INFO:root:Epoch[76] Validation-accuracy=0.841797
# INFO:root:Epoch[77] Batch [64]	Speed: 39641.67 samples/sec	accuracy=0.845913
# INFO:root:Epoch[77] Train-accuracy=0.833239
# INFO:root:Epoch[77] Time cost=0.195
# INFO:root:Epoch[77] Validation-accuracy=0.841797
# INFO:root:Epoch[78] Batch [64]	Speed: 40042.30 samples/sec	accuracy=0.845913
# INFO:root:Epoch[78] Train-accuracy=0.833239
# INFO:root:Epoch[78] Time cost=0.194
# INFO:root:Epoch[78] Validation-accuracy=0.841797
# INFO:root:Epoch[79] Batch [64]	Speed: 28882.32 samples/sec	accuracy=0.845913
# INFO:root:Epoch[79] Train-accuracy=0.833239
# INFO:root:Epoch[79] Time cost=0.251
# INFO:root:Epoch[79] Validation-accuracy=0.841797
# INFO:root:Epoch[80] Batch [64]	Speed: 28167.88 samples/sec	accuracy=0.845913
# INFO:root:Epoch[80] Train-accuracy=0.833239
# INFO:root:Epoch[80] Time cost=0.238
# INFO:root:Epoch[80] Validation-accuracy=0.841797
# INFO:root:Epoch[81] Batch [64]	Speed: 40111.58 samples/sec	accuracy=0.845913
# INFO:root:Epoch[81] Train-accuracy=0.833239
# INFO:root:Epoch[81] Time cost=0.219
# INFO:root:Epoch[81] Validation-accuracy=0.841797
# INFO:root:Epoch[82] Batch [64]	Speed: 24958.15 samples/sec	accuracy=0.845913
# INFO:root:Epoch[82] Train-accuracy=0.833239
# INFO:root:Epoch[82] Time cost=0.309
# INFO:root:Epoch[82] Validation-accuracy=0.841797
# INFO:root:Epoch[83] Batch [64]	Speed: 25232.23 samples/sec	accuracy=0.845913
# INFO:root:Epoch[83] Train-accuracy=0.833239
# INFO:root:Epoch[83] Time cost=0.296
# INFO:root:Epoch[83] Validation-accuracy=0.841797
# INFO:root:Epoch[84] Batch [64]	Speed: 35151.56 samples/sec	accuracy=0.845913
# INFO:root:Epoch[84] Train-accuracy=0.833239
# INFO:root:Epoch[84] Time cost=0.208
# INFO:root:Epoch[84] Validation-accuracy=0.841797
# INFO:root:Epoch[85] Batch [64]	Speed: 39755.70 samples/sec	accuracy=0.845913
# INFO:root:Epoch[85] Train-accuracy=0.833239
# INFO:root:Epoch[85] Time cost=0.195
# INFO:root:Epoch[85] Validation-accuracy=0.841797
# INFO:root:Epoch[86] Batch [64]	Speed: 39329.40 samples/sec	accuracy=0.845913
# INFO:root:Epoch[86] Train-accuracy=0.833239
# INFO:root:Epoch[86] Time cost=0.197
# INFO:root:Epoch[86] Validation-accuracy=0.841797
# INFO:root:Epoch[87] Batch [64]	Speed: 39471.45 samples/sec	accuracy=0.845913
# INFO:root:Epoch[87] Train-accuracy=0.833239
# INFO:root:Epoch[87] Time cost=0.197
# INFO:root:Epoch[87] Validation-accuracy=0.841797
# INFO:root:Epoch[88] Batch [64]	Speed: 38984.47 samples/sec	accuracy=0.845913
# INFO:root:Epoch[88] Train-accuracy=0.833239
# INFO:root:Epoch[88] Time cost=0.198
# INFO:root:Epoch[88] Validation-accuracy=0.841797
# INFO:root:Epoch[89] Batch [64]	Speed: 38939.31 samples/sec	accuracy=0.845913
# INFO:root:Epoch[89] Train-accuracy=0.833239
# INFO:root:Epoch[89] Time cost=0.197
# INFO:root:Epoch[89] Validation-accuracy=0.841797
# INFO:root:Epoch[90] Batch [64]	Speed: 39577.66 samples/sec	accuracy=0.845913
# INFO:root:Epoch[90] Train-accuracy=0.833239
# INFO:root:Epoch[90] Time cost=0.196
# INFO:root:Epoch[90] Validation-accuracy=0.841797
# INFO:root:Epoch[91] Batch [64]	Speed: 39470.00 samples/sec	accuracy=0.845913
# INFO:root:Epoch[91] Train-accuracy=0.833239
# INFO:root:Epoch[91] Time cost=0.197
# INFO:root:Epoch[91] Validation-accuracy=0.841797
# INFO:root:Epoch[92] Batch [64]	Speed: 39621.56 samples/sec	accuracy=0.845913
# INFO:root:Epoch[92] Train-accuracy=0.833239
# INFO:root:Epoch[92] Time cost=0.197
# INFO:root:Epoch[92] Validation-accuracy=0.841797
# INFO:root:Epoch[93] Batch [64]	Speed: 39521.39 samples/sec	accuracy=0.845913
# INFO:root:Epoch[93] Train-accuracy=0.833239
# INFO:root:Epoch[93] Time cost=0.196
# INFO:root:Epoch[93] Validation-accuracy=0.841797
# INFO:root:Epoch[94] Batch [64]	Speed: 39168.36 samples/sec	accuracy=0.845913
# INFO:root:Epoch[94] Train-accuracy=0.833239
# INFO:root:Epoch[94] Time cost=0.196
# INFO:root:Epoch[94] Validation-accuracy=0.841797
# INFO:root:Epoch[95] Batch [64]	Speed: 39434.85 samples/sec	accuracy=0.845913
# INFO:root:Epoch[95] Train-accuracy=0.833239
# INFO:root:Epoch[95] Time cost=0.195
# INFO:root:Epoch[95] Validation-accuracy=0.841797
# INFO:root:Epoch[96] Batch [64]	Speed: 39342.73 samples/sec	accuracy=0.845913
# INFO:root:Epoch[96] Train-accuracy=0.833239
# INFO:root:Epoch[96] Time cost=0.197
# INFO:root:Epoch[96] Validation-accuracy=0.841797
# INFO:root:Epoch[97] Batch [64]	Speed: 39004.20 samples/sec	accuracy=0.845913
# INFO:root:Epoch[97] Train-accuracy=0.833239
# INFO:root:Epoch[97] Time cost=0.198
# INFO:root:Epoch[97] Validation-accuracy=0.841797
# INFO:root:Epoch[98] Batch [64]	Speed: 39409.24 samples/sec	accuracy=0.845913
# INFO:root:Epoch[98] Train-accuracy=0.833239
# INFO:root:Epoch[98] Time cost=0.196
# INFO:root:Epoch[98] Validation-accuracy=0.841797
# INFO:root:Epoch[99] Batch [64]	Speed: 39527.39 samples/sec	accuracy=0.845913
# INFO:root:Epoch[99] Train-accuracy=0.833239
# INFO:root:Epoch[99] Time cost=0.197
# INFO:root:Epoch[99] Validation-accuracy=0.841797
# Accuracy: 84.1796875 %

# %%
# save a model to mymodel-symbol.json and mymodel-0100.params
prefix = 'DDNN_SVM'
epoch = 100
mod.save_checkpoint(prefix, epoch)

# load model back
model_loaded = mx.model.FeedForward.load(prefix, epoch)
# Out:
# INFO:root:Saved checkpoint to "DDNN_SVM-0100.params"

# %%
prob = model_loaded.predict(val_iters)
logging.info('Finish predict of DDNN + SVM...')
# Check the accuracy from prediction
val_iters.reset()

y_batch = []
for dbatch in val_iters:
    label = dbatch.label[0].asnumpy()
    pad = val_iters.getpad()
    real_size = label.shape[0] - pad
    y_batch.append(label[0:real_size])
y = np.concatenate(y_batch)

# get prediction label 
py = np.argmax(prob, axis=1)
acc1 = float(np.sum(py == y)) / len(y)
logging.info('Test accuracy = %f', acc1)
cfn_matrix=confusion_matrix(y,py)
print(classification_report (y,py))
print(cfn_matrix)
# Out:
# INFO:root:Finish predict of DDNN + SVM...
# INFO:root:Test accuracy = 0.841817
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00       404
#         1.0       0.84      1.00      0.91      2150
#
# avg / total       0.71      0.84      0.77      2554
#
# [[   0  404]
#  [   0 2150]]
